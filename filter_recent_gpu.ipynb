# %% [raw]
# Projet NoSQL

# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
import datetime

# %%
client = pymongo.MongoClient()
database = client['exercices']
collection_gpu = database['gpu']

# %%
df_gpu = pd.read_csv("./All_GPUs.csv", delimiter=';')
df_gpu.head()
# Out:
#   Architecture Best_Resolution Boost_Clock Core_Speed  DVI_Connection  \
# 0  Tesla G92b              NaN         NaN    738 MHz             2.0
# 1     R600 XT       1366 x 768         NaN       \n-              2.0
# 2    R600 PRO       1366 x 768         NaN       \n-              2.0
# 3       RV630       1024 x 768         NaN       \n-              2.0
# 4       RV630       1024 x 768         NaN       \n-              2.0
#
#   Dedicated Direct_X  DisplayPort_Connection  HDMI_Connection Integrated  ...  \
# 0       Yes  DX 10.0                     NaN              0.0         No  ...
# 1       Yes    DX 10                     NaN              0.0         No  ...
# 2       Yes    DX 10                     NaN              0.0         No  ...
# 3       Yes    DX 10                     NaN              0.0         No  ...
# 4       Yes    DX 10                     NaN              0.0         No  ...
#
# ...

# %%
# df_gpu = pd.read_csv("./All_GPUs.csv", delimiter=';')
# df_gpu = df_gpu.head(50)
# df_gpu

# %%
#df_gpu = df_gpu[['Architecture','Best_Resolution','Core_Speed','Dedicated','Integrated','Manufacturer','Max_Power','Memory','Memory_Bandwidth','Memory_Bus','Memory_Speed','Name','Process','Texture_Rate']]
#df_gpu

# %%
#df_gpu = df_gpu[['Release_Date']]
df_gpu['year'] = df_gpu['Release_Date'].str[8:]
df_gpu['Release_Date'] = pd.to_datetime(df_gpu['Release_Date'], errors='coerce')
#df_gpu = df_gpu.head(50)
df_gpu
# Out:
#      Architecture Best_Resolution Boost_Clock Core_Speed  DVI_Connection  \
# 0     Tesla G92b              NaN         NaN    738 MHz             2.0
# 1        R600 XT       1366 x 768         NaN       \n-              2.0
# 2       R600 PRO       1366 x 768         NaN       \n-              2.0
# 3          RV630       1024 x 768         NaN       \n-              2.0
# 4          RV630       1024 x 768         NaN       \n-              2.0
# ...           ...             ...         ...        ...             ...
# 3401       MCP61              NaN         NaN       \n-              1.0
# 3402       MCP61              NaN         NaN       \n-              0.0
# 3403       MCP51              NaN         NaN       \n-              0.0
# 3404       MCP51              NaN         NaN       \n-              NaN
# 3405        NV43              NaN         NaN       \n-              1.0
#
#      Dedicated Direct_X  DisplayPort_Connection  HDMI_Connection Integrated  \
# ...

# %%
df_gpu = df_gpu.sort_values('year')
df_gpu = df_gpu.loc[df_gpu['year'].str[0:1] == "2"]
df_gpu = df_gpu.astype({'year': int})
df_gpu
# Out:
#                  Architecture Best_Resolution Boost_Clock Core_Speed  \
# 3396                    NV15              NaN         NaN       \n-
# 1645                     NV6              NaN         NaN       \n-
# 3364                    NV11              NaN         NaN       \n-
# 3368                    NV15              NaN         NaN       \n-
# 3360                    NV16              NaN         NaN       \n-
# ...                       ...             ...         ...        ...
# 1436   GCN 1.3 Polaris 20 XL      1920 x 1080   1293 MHz        \n-
# 1435   GCN 1.3 Polaris 20 XL      1920 x 1080   1293 MHz        \n-
# 1434  GCN 1.3 Polaris 20 XTX      2560 x 1440   1340 MHz        \n-
# 1442   GCN 1.3 Polaris 20 XL      1920 x 1080   1268 MHz        \n-
# 1443   GCN 1.3 Polaris 20 XL      1920 x 1080   1268 MHz        \n-
#
#       DVI_Connection Dedicated Direct_X  DisplayPort_Connection  \
# 3396             0.0       Yes   DX 7.0                     NaN
# ...

# %%
#cur = collection_gpu.find({'year':{'$gte':2015}}).sort("year", -1).limit(15)
#cur 
df_gpu = df_gpu.loc[df_gpu['year'] > 2015]
df_gpu = df_gpu[['Architecture','Best_Resolution','Core_Speed','Dedicated','Integrated','Manufacturer','Max_Power','Memory','Memory_Bandwidth','Memory_Bus','Memory_Speed','Name','Process','Release_Date','Texture_Rate','year']]
df_gpu
# Out:
#                  Architecture Best_Resolution Core_Speed Dedicated Integrated  \
# 1337       GCN 1.3 Baffin XT       1600 x 900   1090 MHz       Yes         No
# 1331       GCN 1.3 Baffin XT       1600 x 900   1090 MHz       Yes         No
# 1332   GCN 1.3 Ellesmere PRO      1920 x 1080    926 MHz       Yes         No
# 1333       GCN 1.3 Baffin XT       1600 x 900   1090 MHz       Yes         No
# 1319   GCN 1.3 Ellesmere PRO      1920 x 1080    926 MHz       Yes         No
# ...                       ...             ...        ...       ...        ...
# 1436   GCN 1.3 Polaris 20 XL      1920 x 1080       \n-        Yes         No
# 1435   GCN 1.3 Polaris 20 XL      1920 x 1080       \n-        Yes         No
# 1434  GCN 1.3 Polaris 20 XTX      2560 x 1440       \n-        Yes         No
# 1442   GCN 1.3 Polaris 20 XL      1920 x 1080       \n-        Yes         No
# 1443   GCN 1.3 Polaris 20 XL      1920 x 1080       \n-        Yes         No
#
# ...

# %%
df_gpu.to_csv("gpu.csv", index=False, sep=";")
